# %%
import json
import os
ROOT = './data/'
file_path = os.path.join(ROOT, 'train_data.jsonl')

with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# %%
import random
from tqdm import tqdm

with open(ROOT, 'law.json', 'r') as file:
    l_data = json.load(file)

def search_content(law):
    num = law.split("第")[1].split("條")[0]
    l = law.split("第")[0]
    
    if l in l_data.keys():
        law_dict = l_data[l]
        list_law_dict= list(law_dict.keys())
        ids = (list_law_dict).index(f'第 {num} 條')
        pre_range = max(0, ids-5)
        post_range = min(len(list_law_dict), ids+5)
        # print(ids, pre_range, post_range)
        content = []
        for c_i in range(pre_range, post_range):
            name = list_law_dict[c_i].replace(' ','')
            content.append(f'{l}{name}:'+l_data[l][list_law_dict[c_i]].replace(' ',''))       
        random.shuffle(content)
        # print(content)
        
        n_content = []
        
        cont = 0
        while(1):
            cont+=1
            random_idx = random.randint(0, len(list_law_dict))
            random_pre_range = max(0, random_idx-2)
            random_post_range = min(len(list_law_dict), random_idx+2)
            if ids> random_post_range or ids<random_pre_range:
                break
            if cont >10:
                return '/n'.join(content)
            
        for c_i in range(random_pre_range, random_post_range):
            name = list_law_dict[c_i].replace(' ','')
            n_content.append(f'{l}{name}:'+l_data[l][list_law_dict[c_i]].replace(' ','')) 

        return '/n'.join(content), '/n'.join(n_content)
        
    else:
        return 'N/A'

dict = []

for idx, d in enumerate(tqdm(data)):
    # label = d['label'].split(',')
    try:
        scene = d['title']+ d['question']
    except:
        print(d['title'], d['question'])
        scene = d['title']
    

    tmp_dict = {}  
    tmp_dict['instruction'] = f'判斷以下情境，與台灣那些法律條文最相關'
    tmp_dict['input'] = f'情境：{scene}'
    tmp_dict['output'] = d['label']
    # # dict.append(tmp_dict)
    # neg_tmp_dict = {}  
    # neg_tmp_dict['instruction'] = f'參考台灣部份法律條文，判斷以下情境，是否有相關條文，與那條法律條文最相關'
    # neg_tmp_dict['input'] = f'法律條文:{content[1]},\n情境： {scene}'
    # neg_tmp_dict['output'] = '否,無相關'
    dict.extend([tmp_dict])
    # print(tmp_dict)
    # print(dict)
    # break
# Out:
# 100%|██████████| 1175/1175 [00:00<00:00, 919117.34it/s]
# 肇事逃逸算是公訴罪嗎？ None
# 父親娶的外籍新娘會來翻我們的東西 且企圖要開我們的房間門 能有法律提告嗎 None
# 立委言論免責權的法律依據是什麼？立委走進立法院，就進入被保護的區域嗎？ None
# 新聞報導華映公司大量解僱勞工，又欠工資，勞動部說負責人被禁止出國。請問要解僱多少人才算是大量解僱勞工 None
# 法庭活動原則上是公開的，在公開案件中，可以要求法庭以直播方式轉播法庭實況，讓一般民眾可以方便觀看嗎？ None
# 車禍當時遵守交通規則，之後進入刑事訴訟程序的話，檢察官或法官怎麼判斷駕駛有沒有過失？ None
# 公司團體保險的理賠金可以抵充雇主的職災責任嗎? None
# 婚前受贈股權，婚後公司盈餘分配與公司結束清算分配，各是屬於婚前或婚後財產？ None
# 兩方不愉快說自己有錄音，疑似將來會控告我性騷擾，請問法律有說幾年內不提告的話，就會失效嗎？ None
# 原廠原裝手機拆下來的零件（零件上印有原廠註冊商標，且零件未有改造或變更），作為手機商品維修用，是否有違反商標法？ None
# 派遣人員，今天工作中手指受傷需要照x光，但是費用雇主不理不睬。 None
# 為何車禍受傷的人沒戴安全帽只能是與有過失、不能是因過關係不具備? None
# 網路購物時，如果買家沒有取貨，賣家可以尋求法律補償嗎？ None
# 若車輛停在騎樓前影響他人車輛出入，是否違法交通秩序的相關法律？ None
# 公投內容不能包含哪些項目？ None
# A在臉書上轉寄了一張有射及色情的迷因(臉書社團中發的)給B這樣會涉及到法律問題嗎? None
# 晚上拿鋤頭到屋頂破會地磚 None
# 因為一些特殊原因，父母兩人都不能行使監護權的時候，怎麼辦？ None
# 本社區是全面禁止吸菸的，鄰居在廁所抽煙導致房間煙味瀰漫。反應多次都沒有下文，有何方法可以解決？ None
# 在網路上簽賭，不是真的有一群人聚在同一個實際的地點賭博，會違法嗎？ None
# 請問定期契約到期，沒有被續聘，不可以請領資遣費，那可以取得失業給付嗎？ None
# 公務車輛違規停車如何處理 None
# 於前公司離職後,因為在職時加班而帶回家的文件或郵件是否應銷毀或刪除? None
# 在百貨公司買耳環七天之內發現有瑕疵、可以要求退貨嗎 None
# 土地佔用 None
# 誰可以提出告訴？常聽到的「保留法律追訴權」就是指暫緩告訴嗎？ None
# 誤以為屍體而殺之，請問是無罪還是未遂 None
# 我男友的阿嬤 是我阿公的親妹妹 這樣可以結婚嗎？ None
# 哪些資料會是個人資料？有可能某些資料特別受到保護嗎？ None
# 為什麼民法繼承關於繼承開始的時間點會設在呼吸、心跳停止？腦死一般不用做判斷死亡時間點？ None
# 在公園健走被路面突出裂縫絆倒受傷骨折要向誰申請賠償？謝謝 None
# 從一審上訴到二審，是文字審，還是庭審？ None
# 請問被民眾檢舉交通違規，後來申訴成功撤銷罰單，是否可對檢舉人提告民事精神賠償或誣告？ None
# 第一順位已送件拋棄繼承 第二順位何時可開始繼承 None
# 我想請問一下，因為傷害罪收到法院的【刑事簡易判決】還可以跟對方和解嗎？和解後，對方可不可以撤回告訴？ None
# 甲擁有一棟附有庭院的房子，若乙將空拍機開到甲的庭院上空，甲是否能將空拍機擊落？ None
# 想要把房子「贈與」給子女，該如何處理？贈與稅是多少？ None
# 請問未經父母同意，小孩讓陌生人進入，陌生人算侵入住宅罪嗎？ None
# 請問被以洗錢防制判6個月，能申請社會勞動服務嗎 None
# 請問在學校被霸凌後轉學還可以提告嗎 None
# 移工的親人過世，移工繼續留在臺灣的話，可否請喪假呢？ None
# 法律對生理假的保障是什麼？需要相關資料作為證明嗎？ None
# 我姐姐(血緣關係非法律關係，即法律上無關係)被鄰居提告，委任我為訴訟代理人，我非律師也非法律相關的科 None
# 甲受死亡宣告後，遺產由妻子乙兩子丙丁三人平分，若甲又生還，那乙丙丁繼承的遺產怎麼辦？ None
# 違反絕對必要事項之法律效力如何？ None
# 亂打沒有顯示號碼的電話，是否構成騷擾？ None
# 如果在車禍中死亡，死者家屬可以向肇事者求償哪些費用？ None
# Line對話訊息是否可當作訴訟證據？ 另外公佈Line對話內容，是否侵犯對方隱私？ None
# 想請問具體危險犯以及實害犯的差異為何？ None
# 請問假如我今天跟別人在遊戲上打賭說單挑輸的送造型好了 但是我反悔了 請問這會被告嗎 None
# 請問如果在性侵犯的旁邊目睹一切事情發生，但卻沒有設法阻止，這樣算不算共犯？ None
# 飛車搶劫的犯人，搶走包包之後，發現包包內沒有值錢的東西，就把包包丟在路邊，這樣會成立犯罪嗎？ None
# 在性別平等教育法裡，有規範學生對教師的性騷擾嗎? None
# 甲將兩棟房屋分別贈送給其八歲之子乙及六歲之女丙，請問該贈與契約之效力如何? None
# 大學生平時皆以腳踏車為交通工具，當發生事故或是意外時，腳踏車是否與汽機車一樣需要負刑事、行政責任等？ None
# 請問學說及實務擄人勒贖既遂的時間點為何？ None
# A將珠寶寄託於C銀行的保險箱，卻因B侵入因此而失竊，試問A得為之請求？以及C銀行得為之主張？ None
# 知道有些犯強盜罪的情況，會加重處罰，請問是哪些情況呢？另外，為什麼要制定刑罰很重的強盜罪結合犯呢？ None
# 不好意思請問僅砍斷拇指算是重傷嗎？還是仍算傷害呢？ None
# 要求警方出示臨檢意議單警方未出示是否能拒決配合（交通違規，警方無具體證據） None
# 投保了人身保險的退休人士，如果之後改為漁民，需要告訴保險公司嗎？ None
# 父親在我兒時就離開家，前幾天得知他再1081125過世，因為擔心他會留下債務，請問要如何辦拋棄繼承 None
# 因應COVID-19疫情（三）疫苗接種假、勞工權益、移工權益，哪些是我需要知道的法律問題？ None
# 外配的父親去世！可以請喪假跟準備什麼文件 None
# 三聯單是什麼？如果警察依法要開三聯單但沒有開，該怎麼辦？ None
# 當再審之訴啟動，可否有阻卻執行之效力？ None
# 如果有人把屋主要拆掉的房子重新粉刷，可以要求屋主給予報酬嗎？ None
# 法律對婚假的保障是什麼？婚假包括假日嗎？ None
# 若對方為執行車且向我示意先過，我未打方向燈切出來對方將我撞倒，肇責比大概多少呢？ None
# 我老公觸犯森林法被判一年半目前在宜蘭三星監獄那是否能申請假釋出獄 None
# 我很好奇，重機上國道因認現階段未達開放行駛之條件，那這條件是什麼?即然立法不執行何來限制條件問題? None
# 因應COVID-19疫情（一），戴口罩、快篩實名制、假訊息，哪些是我需要知道的法律問題？ None

# %%
(dict[0])
# Out:
# {'instruction': '判斷以下情境，與台灣那些法律條文最相關',
#  'input': '情境：帶手指虎打傷人，手指虎會被「沒收」還是「沒入」？知道沒收是刑法，沒入是行政法。\n\r\n單純持有違禁品（手指虎）會遭到沒收，\r\n但用違禁品傷人，是會被「沒收」還是「沒入」呢？',
#  'output': '中華民國刑法第277條,中華民國刑法第38條,社會秩序維護法第22條,社會秩序維護法第87條,行政罰法第26條'}

# %%
file_path = "./LLaMA-Factory/data/law_data_step1.json"

# Save the list as a JSON file
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(dict, file, ensure_ascii=False, indent=4)
